# %% [markdown]
# <a href="https://colab.research.google.com/github/gdnoon/Coursera_codes/blob/Introduction-to-TensorFlow/Linear_regression_with_1_neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install tensorflow==2.5.0
# Out:
# ...
#      |████████████████████████████████| 454.3 MB 16 kB/s
# ...
#      |████████████████████████████████| 1.2 MB 46.9 MB/s
# ...
#      |████████████████████████████████| 462 kB 75.3 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 51.3 MB/s
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68706 sha256=ef7ee52e631718ba8c3218f21135aa3ae6f7bdf3d4b11e610c1b51ed72dc59d2
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.42.0
#     Uninstalling grpcio-1.42.0:
#       Successfully uninstalled grpcio-1.42.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.13.3
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

print(tf.__version__)
# Out:
# 2.5.0

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# simplest possible neural network. It has 1 layer, and that layer has 1 neuron, and the input shape to it is just 1 value.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# 'STOCHASTIC GRADIENT DESCENT' for the optimizer

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 269ms/step - loss: 0.5646
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.5521
# Epoch 3/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5401
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5285
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.5172
# Epoch 6/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5063
# Epoch 7/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4956
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4853
# Epoch 9/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4751
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4652
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4556
# Epoch 12/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4462
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.987688]]
